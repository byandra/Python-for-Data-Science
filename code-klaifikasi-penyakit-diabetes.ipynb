# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd

# %%
# Load the diabetes dataset
df = pd.read_csv('/kaggle/input/diabetes/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
#akses atribut 
df.shape

# %%
df = pd.read_csv('/kaggle/input/diabetes/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
df.tail()

# %%
df.info()

# %%
df.describe().T

# %%
df.isnull().any()

# %%
# Replacing the 0 values from ['Glucose','BloodPressure','SkinThickness','Insulin','BMI'] by NaN
df_copy = df.copy(deep=True)
df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)
df_copy.isnull().sum()

# %%
p = df_copy.hist(figsize = (14,14))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('/kaggle/input/diabetes/diabetes.csv')

X = df.drop('Outcome', axis=1)
y = df['Outcome']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

model.summary()

# Evaluasi model pada set pengujian
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'\nAkurasi pengujian: {test_acc}')
# Out:
# Epoch 1/50
# 40/40 [==============================] - 1s 9ms/step - loss: 0.6997 - accuracy: 0.5406 - val_loss: 0.6403 - val_accuracy: 0.7094
# Epoch 2/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5964 - accuracy: 0.7172 - val_loss: 0.5729 - val_accuracy: 0.7188
# Epoch 3/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5252 - accuracy: 0.7406 - val_loss: 0.5379 - val_accuracy: 0.7156
# Epoch 4/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4857 - accuracy: 0.7578 - val_loss: 0.5258 - val_accuracy: 0.7125
# Epoch 5/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4660 - accuracy: 0.7711 - val_loss: 0.5206 - val_accuracy: 0.7250
# Epoch 6/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.4546 - accuracy: 0.7734 - val_loss: 0.5146 - val_accuracy: 0.7250
# Epoch 7/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4465 - accuracy: 0.7836 - val_loss: 0.5106 - val_accuracy: 0.7344
# Epoch 8/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4399 - accuracy: 0.7844 - val_loss: 0.5068 - val_accuracy: 0.7375
# Epoch 9/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4361 - accuracy: 0.7859 - val_loss: 0.5045 - val_accuracy: 0.7437
# Epoch 10/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4313 - accuracy: 0.7898 - val_loss: 0.5011 - val_accuracy: 0.7500
# Epoch 11/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4269 - accuracy: 0.7891 - val_loss: 0.4987 - val_accuracy: 0.7563
# Epoch 12/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4231 - accuracy: 0.7945 - val_loss: 0.4956 - val_accuracy: 0.7594
# Epoch 13/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.8023 - val_loss: 0.4954 - val_accuracy: 0.7531
# Epoch 14/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4181 - accuracy: 0.8070 - val_loss: 0.4931 - val_accuracy: 0.7563
# Epoch 15/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4138 - accuracy: 0.8062 - val_loss: 0.4925 - val_accuracy: 0.7531
# Epoch 16/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4116 - accuracy: 0.8047 - val_loss: 0.4915 - val_accuracy: 0.7594
# Epoch 17/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4089 - accuracy: 0.8102 - val_loss: 0.4895 - val_accuracy: 0.7563
# Epoch 18/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.8062 - val_loss: 0.4881 - val_accuracy: 0.7469
# Epoch 19/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4027 - accuracy: 0.8133 - val_loss: 0.4859 - val_accuracy: 0.7531
# Epoch 20/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4008 - accuracy: 0.8227 - val_loss: 0.4845 - val_accuracy: 0.7531
# Epoch 21/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3980 - accuracy: 0.8188 - val_loss: 0.4823 - val_accuracy: 0.7531
# Epoch 22/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.8234 - val_loss: 0.4799 - val_accuracy: 0.7500
# Epoch 23/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3917 - accuracy: 0.8211 - val_loss: 0.4800 - val_accuracy: 0.7625
# Epoch 24/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3898 - accuracy: 0.8266 - val_loss: 0.4771 - val_accuracy: 0.7531
# Epoch 25/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3884 - accuracy: 0.8266 - val_loss: 0.4768 - val_accuracy: 0.7563
# Epoch 26/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3853 - accuracy: 0.8258 - val_loss: 0.4744 - val_accuracy: 0.7563
# Epoch 27/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3839 - accuracy: 0.8234 - val_loss: 0.4713 - val_accuracy: 0.7594
# Epoch 28/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3810 - accuracy: 0.8281 - val_loss: 0.4693 - val_accuracy: 0.7594
# Epoch 29/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3783 - accuracy: 0.8289 - val_loss: 0.4695 - val_accuracy: 0.7594
# Epoch 30/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3777 - accuracy: 0.8273 - val_loss: 0.4677 - val_accuracy: 0.7563
# Epoch 31/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3752 - accuracy: 0.8320 - val_loss: 0.4649 - val_accuracy: 0.7594
# Epoch 32/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3721 - accuracy: 0.8336 - val_loss: 0.4647 - val_accuracy: 0.7563
# Epoch 33/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3699 - accuracy: 0.8328 - val_loss: 0.4611 - val_accuracy: 0.7656
# Epoch 34/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.3684 - accuracy: 0.8383 - val_loss: 0.4619 - val_accuracy: 0.7594
# Epoch 35/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3660 - accuracy: 0.8352 - val_loss: 0.4619 - val_accuracy: 0.7594
# Epoch 36/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3650 - accuracy: 0.8438 - val_loss: 0.4607 - val_accuracy: 0.7563
# Epoch 37/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.8391 - val_loss: 0.4575 - val_accuracy: 0.7594
# Epoch 38/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3608 - accuracy: 0.8375 - val_loss: 0.4568 - val_accuracy: 0.7594
# Epoch 39/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3589 - accuracy: 0.8367 - val_loss: 0.4545 - val_accuracy: 0.7625
# Epoch 40/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3582 - accuracy: 0.8422 - val_loss: 0.4538 - val_accuracy: 0.7563
# Epoch 41/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3557 - accuracy: 0.8422 - val_loss: 0.4570 - val_accuracy: 0.7594
# Epoch 42/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3532 - accuracy: 0.8430 - val_loss: 0.4526 - val_accuracy: 0.7594
# Epoch 43/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3515 - accuracy: 0.8445 - val_loss: 0.4512 - val_accuracy: 0.7625
# Epoch 44/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3488 - accuracy: 0.8492 - val_loss: 0.4479 - val_accuracy: 0.7625
# Epoch 45/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3476 - accuracy: 0.8445 - val_loss: 0.4493 - val_accuracy: 0.7625
# Epoch 46/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3441 - accuracy: 0.8508 - val_loss: 0.4494 - val_accuracy: 0.7625
# Epoch 47/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3430 - accuracy: 0.8547 - val_loss: 0.4484 - val_accuracy: 0.7625
# Epoch 48/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3419 - accuracy: 0.8500 - val_loss: 0.4479 - val_accuracy: 0.7563
# Epoch 49/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3399 - accuracy: 0.8555 - val_loss: 0.4455 - val_accuracy: 0.7719
# Epoch 50/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3394 - accuracy: 0.8586 - val_loss: 0.4436 - val_accuracy: 0.7688
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_95 (Dense)            (None, 32)                288
#
#  dense_96 (Dense)            (None, 16)                528
#
#  dense_97 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 833 (3.25 KB)
# Trainable params: 833 (3.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3745 - accuracy: 0.8325
#
# Akurasi pengujian: 0.8324999809265137
